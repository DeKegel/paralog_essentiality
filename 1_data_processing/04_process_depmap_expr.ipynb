# %% [markdown]
# ## Filter DepMap Expression Data
#
# Filter gene expression file down to cell lines that overlap with cell lines screened + only for paralogs

# %%
import pandas as pd
import os
import re

get_data_path = lambda folders, fname: os.path.normpath(os.environ['3RD_PARTY_DIR']+'/'+'/'.join(folders) +'/'+fname)
get_local_data_path = lambda folders, fname: os.path.normpath('../data/' +'/'.join(folders) +'/'+ fname)

# Input
file_gene_scores = get_local_data_path(['processed', 'depmap19Q1'], 'gene_scores_11_07_19.csv')
file_gene_expr = get_data_path(['depmap', '19Q1'], 'CCLE_depMap_19Q1_TPM.csv')
file_paralogs = get_local_data_path(['processed', 'ensembl93'], 'paralog_summary.csv')

# Output
file_filtered_expr = get_local_data_path(['processed', 'depmap19Q1'], 'filtered_gene_expression.csv')

# %%
all_expr_raw = pd.read_csv(file_gene_expr, index_col=0)

# %%
print(all_expr_raw.shape)
all_expr_raw[:1]
# Out:
# (1165, 57820)
#             TSPAN6 (ENSG00000000003)  TNMD (ENSG00000000005)  \
# ACH-000956                  2.650765                     0.0
#
#             DPM1 (ENSG00000000419)  SCYL3 (ENSG00000000457)  \
# ACH-000956                6.216843                 3.427606
#
#             C1orf112 (ENSG00000000460)  FGR (ENSG00000000938)  \
# ACH-000956                    4.672991               0.014355
#
#             CFH (ENSG00000000971)  FUCA2 (ENSG00000001036)  \
# ACH-000956               0.111031                 5.803744
#
#             GCLC (ENSG00000001084)  NFYA (ENSG00000001167)  \
# ACH-000956                6.900867                5.287251
#
#                         ...                RP11-309M23.1 (ENSGR0000237531)  \
# ACH-000956              ...                                            0.0
#
#             AMDP1 (ENSGR0000237801)  BX649553.1 (ENSGR0000263835)  \
# ACH-000956                      0.0                           0.0
#
#             BX649553.2 (ENSGR0000263980)  BX649553.3 (ENSGR0000264510)  \
# ACH-000956                           0.0                           0.0
#
#             BX649553.4 (ENSGR0000264819)  RN7SL355P (ENSGR0000265350)  \
# ACH-000956                           0.0                          0.0
#
#             MIR3690 (ENSGR0000265658)  AL732314.1 (ENSGR0000266731)  \
# ACH-000956                        0.0                           0.0
#
#             AJ271736.10 (ENSGR0000270726)
# ACH-000956                            0.0
#
# [1 rows x 57820 columns]

# %%
# Extract ensembl ids for column headings
get_gene_id = lambda x: re.search('[\w-]+\s\((\w+)\)', x).group(1)
all_expr = all_expr_raw.rename(columns=get_gene_id)
all_expr[:1]
# Out:
#             ENSG00000000003  ENSG00000000005  ENSG00000000419  \
# ACH-000956         2.650765              0.0         6.216843
#
#             ENSG00000000457  ENSG00000000460  ENSG00000000938  \
# ACH-000956         3.427606         4.672991         0.014355
#
#             ENSG00000000971  ENSG00000001036  ENSG00000001084  \
# ACH-000956         0.111031         5.803744         6.900867
#
#             ENSG00000001167       ...         ENSGR0000237531  \
# ACH-000956         5.287251       ...                     0.0
#
#             ENSGR0000237801  ENSGR0000263835  ENSGR0000263980  \
# ACH-000956              0.0              0.0              0.0
#
#             ENSGR0000264510  ENSGR0000264819  ENSGR0000265350  \
# ACH-000956              0.0              0.0              0.0
#
#             ENSGR0000265658  ENSGR0000266731  ENSGR0000270726
# ACH-000956              0.0              0.0              0.0
#
# [1 rows x 57820 columns]

# %%
all_scores = pd.read_csv(file_gene_scores, index_col=0).set_index('cell_line')

# %%
all_scores[:1]
# Out:
#                 8036     55967    55153    25940     23224    116071  \
# cell_line
# ACH-000601 -0.117838 -0.083374 -0.75716 -0.07252 -0.012776 -0.119112
#
#               114803      1967     23014     29957    ...      128344  \
# cell_line                                             ...
# ACH-000601  0.053607 -1.092377 -0.234541 -0.018627    ...    -0.18303
#
#                55249     84304      5869     57818      5273     84952  \
# cell_line
# ACH-000601 -0.096821 -0.092369  0.004617  0.010656 -0.008256  0.003173
#
#                11046     90594       400
# cell_line
# ACH-000601 -0.062839 -0.016976 -0.154559
#
# [1 rows x 16540 columns]

# %%
paralogs = pd.read_csv(file_paralogs, index_col=0)
paralogs[:1]
# Out:
#         ensembl_id  symbol  entrez_id  percent_matched_in_paralog  \
# 0  ENSG00000000003  TSPAN6       7105                    0.583673
#
#    num_paralogs  WGD
# 0             8  WGD

# %%
# Drop non-overlapping cell lines (with CERES scores) and singletons
expr = all_expr.loc[all_expr.index.isin(all_scores.index), all_expr.columns.isin(paralogs.ensembl_id)]
print(all_expr.shape)
print(expr.shape)
# Out:
# (1165, 57820)
# (554, 11857)

# %%
expr.to_csv(file_filtered_expr)
